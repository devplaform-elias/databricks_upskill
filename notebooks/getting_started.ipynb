# %%
from pyspark.sql.functions import rand

# Generate a random DataFrame with 100 rows and 3 columns
df_random = spark.range(100).select(
    rand().alias("col1"),
    rand().alias("col2"),
    rand().alias("col3")
)

display(df_random)
